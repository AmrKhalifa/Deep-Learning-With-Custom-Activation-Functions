# %%
#! pip install torch torchvision
import torch 
from mandelbrot import NeuralModel, train_model
from data_processor import train_set, test_set
from activations import MandelbrotActivation
import matplotlib.pyplot as plt 
import numpy as np

# %%
output = [[lmbda*x*(1-x) for x in np.linspace(-10,10, 100)] for lmbda in range(-10, 10)]
for z in output:
    plt.plot(np.linspace(-10,10, 100),z)
plt.figure(figsize=(6, 6))
plt.savefig("image.jpg", dpi = 10000)
plt.show()

# %%
use_cuda = True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

batch_size = 512
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
custom_neural_model = NeuralModel(custom = True)
custom_trained_model, loss_trace = train_model(custom_neural_model, train_loader, epochs = 20)

regular_neural_model = NeuralModel(custom = False)
regular_trained_model, regular_loss_trace = train_model(regular_neural_model, train_loader, epochs = 20)
# Out:
# started training ...
# the loss after processing this epoch is:  242.80722105503082
# the loss after processing this epoch is:  102.12662523984909
# the loss after processing this epoch is:  58.98583823442459
# the loss after processing this epoch is:  51.61548551917076
# the loss after processing this epoch is:  47.8158096075058
# the loss after processing this epoch is:  45.42645871639252
# the loss after processing this epoch is:  43.64262220263481
# the loss after processing this epoch is:  42.17259472608566
# the loss after processing this epoch is:  40.94763147830963
# the loss after processing this epoch is:  39.90467311441898
# the loss after processing this epoch is:  39.017344906926155
# the loss after processing this epoch is:  38.234581023454666
# the loss after processing this epoch is:  37.52760989964008
# the loss after processing this epoch is:  36.900914907455444
# the loss after processing this epoch is:  36.30648013949394
# the loss after processing this epoch is:  35.75835473835468
# the loss after processing this epoch is:  35.2872793674469
# the loss after processing this epoch is:  34.84363840520382
# the loss after processing this epoch is:  34.42424236238003
# the loss after processing this epoch is:  34.05657632648945
# Training completed.
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=
# started training ...
# the loss after processing this epoch is:  147.05407017469406
# the loss after processing this epoch is:  60.08357810974121
# the loss after processing this epoch is:  48.1737065911293
# the loss after processing this epoch is:  43.34614598751068
# the loss after processing this epoch is:  40.54470953345299
# the loss after processing this epoch is:  38.66543090343475
# the loss after processing this epoch is:  37.25073862075806
# the loss after processing this epoch is:  36.140777707099915
# the loss after processing this epoch is:  35.22298437356949
# the loss after processing this epoch is:  34.49372275173664
# the loss after processing this epoch is:  33.838524639606476
# the loss after processing this epoch is:  33.28849205374718
# the loss after processing this epoch is:  32.73561550676823
# the loss after processing this epoch is:  32.247328251600266
# the loss after processing this epoch is:  31.839144229888916
# the loss after processing this epoch is:  31.410306245088577
# the loss after processing this epoch is:  31.048044562339783
# the loss after processing this epoch is:  30.680985279381275
# the loss after processing this epoch is:  30.357300147414207
# the loss after processing this epoch is:  30.064419619739056
# Training completed.
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=

# %%
plt.plot(loss_trace, label = 'Mandelbrot')
plt.plot(regular_loss_trace, label = 'ReLU')

plt.legend()
plt.show()

# %%
def test_model(model, test_data):
    model.eval()
    model.to(device)
    correct = 0

    for batch in test_data:
        batch_images, batch_labels = batch

        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)

        predictions = model(batch_images)

        predictions = predictions.data.max(1, keepdim=True)[1]
        correct += predictions.eq(batch_labels.data.view_as(predictions)).sum()

    accuracy = float(correct.item() / len(test_loader.dataset))

    print("The classifier accuracy is: ", 100 * accuracy)
    
    return accuracy

# %%
test_model(custom_neural_model, test_loader)
test_model(regular_neural_model, test_loader)
# Out:
# The classifier accuracy is:  86.59
# The classifier accuracy is:  87.6
# 0.876
