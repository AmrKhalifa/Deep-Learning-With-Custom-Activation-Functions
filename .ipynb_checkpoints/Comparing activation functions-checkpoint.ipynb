# %%
#! pip install torch torchvision
import torch 
from mandelbrot import NeuralModel, train_model, FCModel
from data_processor import train_set, test_set
from activations import MandelbrotActivation
import matplotlib.pyplot as plt 
import numpy as np

# %%
output = [[lmbda*x*(1-x) for x in np.linspace(-10,10, 100)] for lmbda in range(-5, 5)]
for i, z in enumerate(output):
    plt.plot(np.linspace(-10,10, 100),z, label = '$\lambda$ = '+str(i))

plt.legend()
plt.savefig("image.png", dpi=250)
plt.show()

# %%
use_cuda = True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

batch_size = 512
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
custom_neural_model = FCModel(custom = True)
custom_trained_model, loss_trace = train_model(custom_neural_model, train_loader, epochs = 20)

regular_neural_model = FCModel(custom = False)
regular_trained_model, regular_loss_trace = train_model(regular_neural_model, train_loader, epochs = 20)
# Out:
# started training ...
# the loss after processing this epoch is:  250.95338451862335
# the loss after processing this epoch is:  110.19563674926758
# the loss after processing this epoch is:  62.19511613249779
# the loss after processing this epoch is:  54.577854573726654
# the loss after processing this epoch is:  50.45490065217018
# the loss after processing this epoch is:  47.682830423116684
# the loss after processing this epoch is:  45.57901909947395
# the loss after processing this epoch is:  43.99638706445694
# the loss after processing this epoch is:  42.690338015556335
# the loss after processing this epoch is:  41.66585524380207
# the loss after processing this epoch is:  40.76096574962139
# the loss after processing this epoch is:  39.943323001265526
# the loss after processing this epoch is:  39.23786361515522
# the loss after processing this epoch is:  38.57451443374157
# the loss after processing this epoch is:  37.983486354351044
# the loss after processing this epoch is:  37.46519699692726
# the loss after processing this epoch is:  36.97477552294731
# the loss after processing this epoch is:  36.510505840182304
# the loss after processing this epoch is:  36.06119802594185
# the loss after processing this epoch is:  35.65734605491161
# Training completed.
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=
# started training ...
# the loss after processing this epoch is:  137.98351603746414
# the loss after processing this epoch is:  58.70987781882286
# the loss after processing this epoch is:  46.56397485733032
# the loss after processing this epoch is:  42.066665798425674
# the loss after processing this epoch is:  39.52709196507931
# the loss after processing this epoch is:  37.86802324652672
# the loss after processing this epoch is:  36.60437053442001
# the loss after processing this epoch is:  35.62396577000618
# the loss after processing this epoch is:  34.81019516289234
# the loss after processing this epoch is:  34.12579479813576
# the loss after processing this epoch is:  33.53976786136627
# the loss after processing this epoch is:  33.04325906932354
# the loss after processing this epoch is:  32.58446329832077
# the loss after processing this epoch is:  32.123663783073425
# the loss after processing this epoch is:  31.721233427524567
# the loss after processing this epoch is:  31.37937006354332
# the loss after processing this epoch is:  31.023487329483032
# the loss after processing this epoch is:  30.734614059329033
# the loss after processing this epoch is:  30.45196805894375
# the loss after processing this epoch is:  30.179322749376297
# Training completed.
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=

# %%
plt.plot(loss_trace, label = 'Mandelbrot')
plt.plot(regular_loss_trace, label = 'ReLU')

plt.legend()
plt.savefig("result.png", dpi=200)
plt.show()

# %%
def test_model(model, test_data):
    model.eval()
    model.to(device)
    correct = 0

    for batch in test_data:
        batch_images, batch_labels = batch

        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)

        predictions = model(batch_images)

        predictions = predictions.data.max(1, keepdim=True)[1]
        correct += predictions.eq(batch_labels.data.view_as(predictions)).sum()

    accuracy = float(correct.item() / len(test_loader.dataset))

    print("The classifier accuracy is: ", 100 * accuracy)
    
    return accuracy

# %%
test_model(custom_neural_model, test_loader)
test_model(regular_neural_model, test_loader)
# Out:
# The classifier accuracy is:  87.36
# The classifier accuracy is:  88.09
# 0.8809
